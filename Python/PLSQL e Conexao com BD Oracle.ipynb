# %% [markdown]
# # Conexão com o Oracle

# %% [markdown]
# ## Instalando PIP

# %%
# !pip install oracledb  # exclamação não se usa mais, agora eh % (pois ele é mais curto)
# Out:
# Collecting oracledb
#   Downloading oracledb-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 29.5 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from oracledb) (42.0.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.2.1->oracledb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.2.1->oracledb) (2.21)
# Installing collected packages: oracledb
# Successfully installed oracledb-2.0.1

# %%
# %pip install cx_Oracle  # exclamação não se usa mais, agora eh %
# Out:
# Collecting cx_Oracle
#   Downloading cx_Oracle-8.3.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (892 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 892.6/892.6 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: cx_Oracle
# Successfully installed cx_Oracle-8.3.0

# %% [markdown]
# ## Instalando Bibliotecas

# %%
import oracledb
import cx_Oracle
import getpass # pegar password através de um input
import pandas as pd
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Acessando o Banco

# %%
# Entrando na conexão
pw = getpass.getpass("Enter password: ")

connection = oracledb.connect(
    user="RM553653",
    password=pw,
    dsn="oracle.fiap.com.br:1521/orcl")

print("Successfully connected to Oracle Database")

cursor = connection.cursor()

cursor.execute("SELECT username FROM all_users ORDER BY username")
for username in cursor:
    print(username)

# %% [markdown]
# ## Iniciando as operações

# %% [markdown]
# * Criando uma Tabela

# %%
# Criando uma nova Tabela
cursor.execute("""
    CREATE TABLE minha_nova_tabela (
        id INT PRIMARY KEY,
        nome VARCHAR2(50),
        descricao VARCHAR2(255)
    )
""")

# %% [markdown]
# * Explorando o Banco

# %%
# Mostrando todas as tabelas
cursor.execute("SELECT table_name FROM user_tables")
for table in cursor:
    print(table)

# %%
# Dando nome
results = cursor.execute("SELECT table_name FROM user_tables")
for abacate in results:
  print(abacate)

# %%
results
# Out:
# <oracledb.Cursor on <oracledb.Connection to RM553653@oracle.fiap.com.br:1521/orcl>>

# %%
results.description
# Out:
# [('TABLE_NAME', <DbType DB_TYPE_VARCHAR>, 128, 128, None, None, False)]

# %% [markdown]
# * Criação das tabelas

# %%
# Criação das tabelas
try:
    cursor.execute("""
        CREATE TABLE clientes (
            cliente_id INT PRIMARY KEY,
            nome VARCHAR2(100),
            email VARCHAR2(100)
        )
    """)

    cursor.execute("""
        CREATE TABLE produtos (
            produto_id INT PRIMARY KEY,
            nome VARCHAR2(100),
            preco DECIMAL(10,2)
        )
    """)

    cursor.execute("""
        CREATE TABLE vendedores (
            vendedor_id INT PRIMARY KEY,
            nome VARCHAR2(100)
        )
    """)

    cursor.execute("""
        CREATE TABLE vendas (
            venda_id INT PRIMARY KEY,
            cliente_id INT,
            produto_id INT,
            vendedor_id INT,
            quantidade INT,
            data_venda DATE,
            FOREIGN KEY (cliente_id) REFERENCES clientes(cliente_id),
            FOREIGN KEY (produto_id) REFERENCES produtos(produto_id),
            FOREIGN KEY (vendedor_id) REFERENCES vendedores(vendedor_id)
        )
    """)

    connection.commit()
    print("Tabelas criadas com sucesso.")
except cx_Oracle.DatabaseError as e:
    print("Erro ao criar tabelas:", e)
finally:
    cursor.close()
    connection.close()
# Out:
# Tabelas criadas com sucesso.

# %%
cursor.execute("SELECT table_name FROM user_tables")
for table in cursor:
    print(table)

# %% [markdown]
# * Inserindo dados na Tabela

# %%
pw = getpass.getpass("Enter password: ")

connection = oracledb.connect(
    user="RM553653",
    password=pw,
    dsn="oracle.fiap.com.br:1521/orcl")

print("Successfully connected to Oracle Database")

cursor = connection.cursor()
# Out:
# Enter password: ··········
# Successfully connected to Oracle Database

# %%
# Inserindo dados nas Tabelas

# Inserindo dados em 'produtos'
for i in range(1, 11):
    cursor.execute(f"""
        INSERT INTO produtos (produto_id, nome, preco)
        VALUES ({i}, 'Produto Eletrônico {i}', {random.uniform(100.0, 1000.0):.2f})
    """)

# Inserindo dados em 'clientes'
for i in range(1, 31):
    cursor.execute(f"""
        INSERT INTO clientes (cliente_id, nome, email)
        VALUES ({i}, 'Cliente Genérico {i}', 'cliente{i}@exemplo.com')
    """)

# Inserindo dados em 'vendedores'
for i in range(1, 11):
    cursor.execute(f"""
        INSERT INTO vendedores (vendedor_id, nome)
        VALUES ({i}, 'Vendedor {i}')
    """)

# Inserindo dados em 'vendas' com valores aleatórios
for i in range(1, 201):
    data_venda = datetime.now() - timedelta(days=random.randint(1, 365))
    cursor.execute(f"""
        INSERT INTO vendas (venda_id, cliente_id, produto_id, vendedor_id, quantidade, data_venda)
        VALUES ({i}, {random.randint(1, 30)}, {random.randint(1, 10)}, {random.randint(1, 10)}, {random.randint(1, 5)}, TO_DATE('{data_venda.strftime('%Y-%m-%d')}', 'YYYY-MM-DD'))
    """)

connection.commit()
print("Dados inseridos com sucesso.")
# Out:
# Dados inseridos com sucesso.

# %% [markdown]
# * Criando uma Viwer com Join

# %%
# Em DESC do Valor Total
try:
    cursor.execute("""
        SELECT v.venda_id, c.nome AS cliente_nome, p.nome AS produto_nome, p.preco, v.quantidade,
        (p.preco * v.quantidade) AS valor_total_venda, vd.nome AS vendedor_nome, v.data_venda
        FROM vendas v
        JOIN clientes c ON v.cliente_id = c.cliente_id
        JOIN produtos p ON v.produto_id = p.produto_id
        JOIN vendedores vd ON v.vendedor_id = vd.vendedor_id
        ORDER BY valor_total_venda DESC
        FETCH FIRST 10 ROWS ONLY
    """)

    results = cursor.fetchall()

    # Convertendo os resultados em um DataFrame
    df = pd.DataFrame(results, columns=['ID da Venda', 'Cliente', 'Produto', 'Preço', 'Quantidade', 'Valor Total da Venda', 'Vendedor', 'Data da Venda'])

    # Exibindo o DataFrame
    print(df)
except cx_Oracle.DatabaseError as e:
    print("Erro ao buscar as maiores vendas:", e)
# Out:
#    ID da Venda              Cliente               Produto   Preço  Quantidade  \
# 0           22  Cliente Genérico 14  Produto Eletrônico 1  954.15           5
# 1          392  Cliente Genérico 29  Produto Eletrônico 1  954.15           5
# 2          388  Cliente Genérico 27  Produto Eletrônico 1  954.15           5
# 3          373  Cliente Genérico 30  Produto Eletrônico 1  954.15           5
# 4           65  Cliente Genérico 20  Produto Eletrônico 1  954.15           5
# 5          343  Cliente Genérico 28  Produto Eletrônico 1  954.15           5
# 6          232   Cliente Genérico 8  Produto Eletrônico 1  954.15           5
# 7          223  Cliente Genérico 14  Produto Eletrônico 1  954.15           5
# 8          125   Cliente Genérico 6  Produto Eletrônico 1  954.15           5
# 9          344  Cliente Genérico 26  Produto Eletrônico 1  954.15           5
#
#    Valor Total da Venda     Vendedor Data da Venda
# 0               4770.75   Vendedor 3    2023-07-14
# 1               4770.75   Vendedor 2    2023-03-04
# 2               4770.75  Vendedor 10    2024-01-05
# 3               4770.75   Vendedor 4    2023-04-14
# 4               4770.75   Vendedor 9    2023-04-21
# 5               4770.75   Vendedor 1    2024-02-06
# 6               4770.75   Vendedor 2    2023-12-11
# 7               4770.75   Vendedor 2    2023-10-23
# 8               4770.75   Vendedor 4    2023-12-16
# 9               4770.75   Vendedor 8    2023-04-01

# %%
df
# Out:
#    ID da Venda              Cliente               Produto   Preço  Quantidade  \
# 0           22  Cliente Genérico 14  Produto Eletrônico 1  954.15           5
# 1          392  Cliente Genérico 29  Produto Eletrônico 1  954.15           5
# 2          388  Cliente Genérico 27  Produto Eletrônico 1  954.15           5
# 3          373  Cliente Genérico 30  Produto Eletrônico 1  954.15           5
# 4           65  Cliente Genérico 20  Produto Eletrônico 1  954.15           5
# 5          343  Cliente Genérico 28  Produto Eletrônico 1  954.15           5
# 6          232   Cliente Genérico 8  Produto Eletrônico 1  954.15           5
# 7          223  Cliente Genérico 14  Produto Eletrônico 1  954.15           5
# 8          125   Cliente Genérico 6  Produto Eletrônico 1  954.15           5
# 9          344  Cliente Genérico 26  Produto Eletrônico 1  954.15           5
#
#    Valor Total da Venda     Vendedor Data da Venda
# 0               4770.75   Vendedor 3    2023-07-14
# 1               4770.75   Vendedor 2    2023-03-04
# 2               4770.75  Vendedor 10    2024-01-05
# 3               4770.75   Vendedor 4    2023-04-14
# 4               4770.75   Vendedor 9    2023-04-21
# 5               4770.75   Vendedor 1    2024-02-06
# 6               4770.75   Vendedor 2    2023-12-11
# 7               4770.75   Vendedor 2    2023-10-23
# 8               4770.75   Vendedor 4    2023-12-16
# 9               4770.75   Vendedor 8    2023-04-01

# %%
# Fazendo com o ORDER BY da Data
try:
    cursor.execute("""
        SELECT v.venda_id, c.nome AS cliente_nome, p.nome AS produto_nome, p.preco, v.quantidade,
        (p.preco * v.quantidade) AS valor_total_venda, vd.nome AS vendedor_nome, v.data_venda
        FROM vendas v
        JOIN clientes c ON v.cliente_id = c.cliente_id
        JOIN produtos p ON v.produto_id = p.produto_id
        JOIN vendedores vd ON v.vendedor_id = vd.vendedor_id
        ORDER BY v.data_venda
    """)

    results = cursor.fetchall()

    # Convertendo os resultados em um DataFrame
    df = pd.DataFrame(results, columns=['ID da Venda', 'Cliente', 'Produto', 'Preço', 'Quantidade', 'Valor Total da Venda', 'Vendedor', 'Data da Venda'])

    # Exibindo o DataFrame
    print(df.to_string(index=False))
except cx_Oracle.DatabaseError as e:
    print("Erro ao buscar as maiores vendas:", e)
# Out:
#  ID da Venda             Cliente               Produto  Preço  Quantidade  Valor Total da Venda    Vendedor Data da Venda
#          392 Cliente Genérico 29  Produto Eletrônico 1 954.15           5               4770.75  Vendedor 2    2023-03-04
#          259  Cliente Genérico 9  Produto Eletrônico 3 817.07           5               4085.35  Vendedor 2    2023-03-07
#          393 Cliente Genérico 23  Produto Eletrônico 8 535.68           2               1071.36  Vendedor 8    2023-03-08
#          117  Cliente Genérico 6  Produto Eletrônico 5 606.13           4               2424.52 Vendedor 10    2023-03-08
#          375 Cliente Genérico 25 Produto Eletrônico 10 455.52           2                911.04  Vendedor 3    2023-03-08
#           54 Cliente Genérico 20  Produto Eletrônico 5 606.13           1                606.13  Vendedor 6    2023-03-08
#          213 Cliente Genérico 19  Produto Eletrônico 9 184.82           1                184.82  Vendedor 7    2023-03-09
#          171 Cliente Genérico 10  Produto Eletrônico 4 787.79           4               3151.16  Vendedor 1    2023-03-09
#           43  Cliente Genérico 6  Produto Eletrônico 9 184.82           3                554.46  Vendedor 1    2023-03-10
#          338 Cliente Genérico 22  Produto Eletrônico 7 823.36           5               4116.80  Vendedor 3    2023-03-10
#           77  Cliente Genérico 3  Produto Eletrônico 1 954.15           1                954.15 Vendedor 10    2023-03-13
#          294 Cliente Genérico 17  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 8    2023-03-13
#          129 Cliente Genérico 24 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 7    2023-03-14
#          359 Cliente Genérico 11  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 2    2023-03-14
#          365  Cliente Genérico 9  Produto Eletrônico 8 535.68           2               1071.36 Vendedor 10    2023-03-15
#          355 Cliente Genérico 28  Produto Eletrônico 9 184.82           1                184.82  Vendedor 3    2023-03-15
#          356  Cliente Genérico 4  Produto Eletrônico 2 128.36           3                385.08  Vendedor 8    2023-03-15
#           12 Cliente Genérico 25  Produto Eletrônico 5 606.13           1                606.13  Vendedor 8    2023-03-18
#          247 Cliente Genérico 16  Produto Eletrônico 5 606.13           1                606.13  Vendedor 3    2023-03-19
#          317 Cliente Genérico 17  Produto Eletrônico 1 954.15           2               1908.30  Vendedor 7    2023-03-19
#          222 Cliente Genérico 21  Produto Eletrônico 1 954.15           1                954.15  Vendedor 1    2023-03-19
#          286 Cliente Genérico 29  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 3    2023-03-21
#          347  Cliente Genérico 2  Produto Eletrônico 4 787.79           2               1575.58  Vendedor 4    2023-03-21
#          264 Cliente Genérico 26 Produto Eletrônico 10 455.52           2                911.04  Vendedor 1    2023-03-22
#          287 Cliente Genérico 20  Produto Eletrônico 1 954.15           3               2862.45  Vendedor 1    2023-03-23
#          123  Cliente Genérico 6  Produto Eletrônico 9 184.82           5                924.10  Vendedor 8    2023-03-23
#          174 Cliente Genérico 25  Produto Eletrônico 5 606.13           4               2424.52  Vendedor 1    2023-03-23
#            4  Cliente Genérico 9  Produto Eletrônico 5 606.13           3               1818.39 Vendedor 10    2023-03-25
#          360 Cliente Genérico 27  Produto Eletrônico 7 823.36           1                823.36  Vendedor 5    2023-03-25
#          280 Cliente Genérico 19  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 6    2023-03-28
#          305 Cliente Genérico 10 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 5    2023-03-28
#          237 Cliente Genérico 26 Produto Eletrônico 10 455.52           2                911.04  Vendedor 4    2023-03-28
#          260  Cliente Genérico 9  Produto Eletrônico 2 128.36           1                128.36  Vendedor 6    2023-03-30
#          272 Cliente Genérico 19  Produto Eletrônico 9 184.82           3                554.46  Vendedor 1    2023-03-30
#           87 Cliente Genérico 29  Produto Eletrônico 1 954.15           2               1908.30  Vendedor 4    2023-03-30
#          379 Cliente Genérico 15  Produto Eletrônico 1 954.15           2               1908.30  Vendedor 2    2023-03-30
#          344 Cliente Genérico 26  Produto Eletrônico 1 954.15           5               4770.75  Vendedor 8    2023-04-01
#          293  Cliente Genérico 5  Produto Eletrônico 6 566.94           1                566.94  Vendedor 6    2023-04-03
#          136 Cliente Genérico 14 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 3    2023-04-03
#          151 Cliente Genérico 11 Produto Eletrônico 10 455.52           5               2277.60  Vendedor 4    2023-04-04
#           92 Cliente Genérico 24  Produto Eletrônico 7 823.36           2               1646.72  Vendedor 2    2023-04-05
#          400  Cliente Genérico 2  Produto Eletrônico 9 184.82           3                554.46 Vendedor 10    2023-04-06
#          203  Cliente Genérico 5  Produto Eletrônico 4 787.79           1                787.79  Vendedor 4    2023-04-06
#          120  Cliente Genérico 1  Produto Eletrônico 2 128.36           2                256.72  Vendedor 9    2023-04-06
#          307  Cliente Genérico 2  Produto Eletrônico 3 817.07           2               1634.14  Vendedor 3    2023-04-07
#          263 Cliente Genérico 25  Produto Eletrônico 1 954.15           3               2862.45  Vendedor 6    2023-04-08
#           69 Cliente Genérico 27 Produto Eletrônico 10 455.52           1                455.52  Vendedor 7    2023-04-09
#            6 Cliente Genérico 27  Produto Eletrônico 5 606.13           3               1818.39  Vendedor 1    2023-04-11
#           53  Cliente Genérico 1  Produto Eletrônico 6 566.94           3               1700.82  Vendedor 8    2023-04-12
#           45 Cliente Genérico 23  Produto Eletrônico 2 128.36           5                641.80 Vendedor 10    2023-04-12
#          328 Cliente Genérico 17  Produto Eletrônico 1 954.15           1                954.15  Vendedor 1    2023-04-12
#          162  Cliente Genérico 6  Produto Eletrônico 8 535.68           2               1071.36  Vendedor 5    2023-04-12
#          334 Cliente Genérico 22  Produto Eletrônico 8 535.68           3               1607.04  Vendedor 2    2023-04-13
#          227 Cliente Genérico 16  Produto Eletrônico 4 787.79           2               1575.58  Vendedor 8    2023-04-13
#          324  Cliente Genérico 9  Produto Eletrônico 3 817.07           3               2451.21 Vendedor 10    2023-04-13
#          189 Cliente Genérico 21  Produto Eletrônico 9 184.82           3                554.46  Vendedor 1    2023-04-13
#          373 Cliente Genérico 30  Produto Eletrônico 1 954.15           5               4770.75  Vendedor 4    2023-04-14
#          109 Cliente Genérico 15  Produto Eletrônico 8 535.68           1                535.68  Vendedor 1    2023-04-15
#          146 Cliente Genérico 13  Produto Eletrônico 2 128.36           4                513.44  Vendedor 1    2023-04-16
#          212  Cliente Genérico 2  Produto Eletrônico 9 184.82           1                184.82  Vendedor 4    2023-04-17
#          218 Cliente Genérico 30  Produto Eletrônico 5 606.13           5               3030.65  Vendedor 6    2023-04-17
#          258 Cliente Genérico 17  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 1    2023-04-17
#          216 Cliente Genérico 20 Produto Eletrônico 10 455.52           1                455.52 Vendedor 10    2023-04-20
#           65 Cliente Genérico 20  Produto Eletrônico 1 954.15           5               4770.75  Vendedor 9    2023-04-21
#          284 Cliente Genérico 25  Produto Eletrônico 3 817.07           4               3268.28  Vendedor 8    2023-04-22
#          141 Cliente Genérico 26  Produto Eletrônico 3 817.07           1                817.07 Vendedor 10    2023-04-22
#          285 Cliente Genérico 17  Produto Eletrônico 6 566.94           5               2834.70  Vendedor 6    2023-04-24
#           42 Cliente Genérico 30  Produto Eletrônico 1 954.15           1                954.15  Vendedor 1    2023-04-24
#          200 Cliente Genérico 14  Produto Eletrônico 5 606.13           5               3030.65  Vendedor 7    2023-04-25
#           32  Cliente Genérico 4  Produto Eletrônico 4 787.79           4               3151.16  Vendedor 8    2023-04-25
#          384 Cliente Genérico 18  Produto Eletrônico 4 787.79           5               3938.95  Vendedor 5    2023-04-25
#          348  Cliente Genérico 8  Produto Eletrônico 3 817.07           4               3268.28  Vendedor 6    2023-04-25
#          336 Cliente Genérico 28  Produto Eletrônico 6 566.94           4               2267.76  Vendedor 6    2023-04-26
#           35 Cliente Genérico 21  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 4    2023-04-27
#           56 Cliente Genérico 18  Produto Eletrônico 7 823.36           2               1646.72  Vendedor 4    2023-04-30
#           71 Cliente Genérico 15  Produto Eletrônico 2 128.36           1                128.36  Vendedor 5    2023-04-30
#          168  Cliente Genérico 3  Produto Eletrônico 1 954.15           2               1908.30  Vendedor 5    2023-04-30
#          211 Cliente Genérico 10  Produto Eletrônico 7 823.36           1                823.36  Vendedor 5    2023-05-01
#           66  Cliente Genérico 6  Produto Eletrônico 7 823.36           3               2470.08  Vendedor 9    2023-05-01
#          226  Cliente Genérico 5  Produto Eletrônico 4 787.79           2               1575.58  Vendedor 5    2023-05-02
#           64 Cliente Genérico 20  Produto Eletrônico 7 823.36           1                823.36  Vendedor 5    2023-05-02
#          292 Cliente Genérico 16  Produto Eletrônico 2 128.36           2                256.72  Vendedor 4    2023-05-03
#           93 Cliente Genérico 25  Produto Eletrônico 9 184.82           5                924.10  Vendedor 6    2023-05-06
#          164  Cliente Genérico 3  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 1    2023-05-06
#           15  Cliente Genérico 5  Produto Eletrônico 1 954.15           3               2862.45  Vendedor 4    2023-05-07
#          190 Cliente Genérico 25  Produto Eletrônico 4 787.79           2               1575.58 Vendedor 10    2023-05-07
#          126 Cliente Genérico 24  Produto Eletrônico 9 184.82           1                184.82  Vendedor 6    2023-05-08
#          180  Cliente Genérico 4  Produto Eletrônico 1 954.15           3               2862.45  Vendedor 8    2023-05-08
#          228  Cliente Genérico 7 Produto Eletrônico 10 455.52           2                911.04  Vendedor 7    2023-05-08
#          145 Cliente Genérico 28  Produto Eletrônico 5 606.13           5               3030.65  Vendedor 5    2023-05-09
#          157 Cliente Genérico 11  Produto Eletrônico 4 787.79           4               3151.16  Vendedor 6    2023-05-10
#           75 Cliente Genérico 27  Produto Eletrônico 6 566.94           3               1700.82  Vendedor 9    2023-05-11
#          207 Cliente Genérico 14  Produto Eletrônico 3 817.07           2               1634.14  Vendedor 1    2023-05-13
#          251 Cliente Genérico 19  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 9    2023-05-13
#          142 Cliente Genérico 10  Produto Eletrônico 2 128.36           5                641.80  Vendedor 9    2023-05-13
#           16 Cliente Genérico 22  Produto Eletrônico 1 954.15           1                954.15  Vendedor 5    2023-05-16
#          214 Cliente Genérico 10  Produto Eletrônico 4 787.79           4               3151.16  Vendedor 3    2023-05-17
#          209  Cliente Genérico 6  Produto Eletrônico 5 606.13           4               2424.52  Vendedor 3    2023-05-19
#          257  Cliente Genérico 4  Produto Eletrônico 5 606.13           4               2424.52  Vendedor 1    2023-05-22
#          350 Cliente Genérico 13  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 2    2023-05-22
#           63 Cliente Genérico 11  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 1    2023-05-23
#          346  Cliente Genérico 9  Produto Eletrônico 9 184.82           5                924.10  Vendedor 7    2023-05-25
#          303 Cliente Genérico 21  Produto Eletrônico 4 787.79           3               2363.37  Vendedor 9    2023-05-25
#          322 Cliente Genérico 26  Produto Eletrônico 5 606.13           1                606.13  Vendedor 7    2023-05-27
#          234 Cliente Genérico 30  Produto Eletrônico 1 954.15           3               2862.45  Vendedor 4    2023-05-27
#          371 Cliente Genérico 27  Produto Eletrônico 7 823.36           1                823.36  Vendedor 4    2023-05-29
#           48 Cliente Genérico 16  Produto Eletrônico 2 128.36           1                128.36  Vendedor 1    2023-05-30
#           91 Cliente Genérico 19  Produto Eletrônico 7 823.36           5               4116.80 Vendedor 10    2023-06-01
#           88 Cliente Genérico 19  Produto Eletrônico 2 128.36           3                385.08  Vendedor 2    2023-06-01
#           46  Cliente Genérico 1  Produto Eletrônico 5 606.13           5               3030.65 Vendedor 10    2023-06-03
#          329  Cliente Genérico 1 Produto Eletrônico 10 455.52           2                911.04  Vendedor 1    2023-06-03
#          144 Cliente Genérico 28  Produto Eletrônico 7 823.36           4               3293.44  Vendedor 9    2023-06-03
#          121 Cliente Genérico 27  Produto Eletrônico 2 128.36           4                513.44  Vendedor 7    2023-06-03
#          265 Cliente Genérico 27  Produto Eletrônico 1 954.15           3               2862.45  Vendedor 2    2023-06-04
#           49 Cliente Genérico 17  Produto Eletrônico 1 954.15           2               1908.30  Vendedor 5    2023-06-05
#          253  Cliente Genérico 9  Produto Eletrônico 3 817.07           2               1634.14  Vendedor 3    2023-06-05
#          368 Cliente Genérico 14  Produto Eletrônico 4 787.79           2               1575.58  Vendedor 7    2023-06-07
#          363 Cliente Genérico 28  Produto Eletrônico 7 823.36           1                823.36  Vendedor 8    2023-06-10
#          339 Cliente Genérico 14  Produto Eletrônico 7 823.36           1                823.36  Vendedor 8    2023-06-11
#          101 Cliente Genérico 27  Produto Eletrônico 5 606.13           4               2424.52  Vendedor 9    2023-06-12
#          248  Cliente Genérico 5  Produto Eletrônico 6 566.94           3               1700.82  Vendedor 9    2023-06-15
#           86 Cliente Genérico 13 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 2    2023-06-16
#          380 Cliente Genérico 24  Produto Eletrônico 7 823.36           2               1646.72  Vendedor 1    2023-06-17
#          295  Cliente Genérico 1  Produto Eletrônico 5 606.13           1                606.13  Vendedor 5    2023-06-17
#           60  Cliente Genérico 9  Produto Eletrônico 9 184.82           1                184.82 Vendedor 10    2023-06-19
#          314  Cliente Genérico 6  Produto Eletrônico 9 184.82           5                924.10  Vendedor 1    2023-06-19
#          220 Cliente Genérico 11  Produto Eletrônico 4 787.79           1                787.79  Vendedor 4    2023-06-21
#           70 Cliente Genérico 13  Produto Eletrônico 2 128.36           4                513.44  Vendedor 9    2023-06-24
#          187  Cliente Genérico 7  Produto Eletrônico 6 566.94           5               2834.70  Vendedor 1    2023-06-25
#           82  Cliente Genérico 1  Produto Eletrônico 2 128.36           5                641.80  Vendedor 9    2023-06-26
#          184 Cliente Genérico 24  Produto Eletrônico 9 184.82           5                924.10  Vendedor 1    2023-06-27
#          167 Cliente Genérico 28  Produto Eletrônico 3 817.07           5               4085.35  Vendedor 2    2023-06-27
#          391 Cliente Genérico 27  Produto Eletrônico 5 606.13           5               3030.65  Vendedor 4    2023-06-28
#          210 Cliente Genérico 18  Produto Eletrônico 3 817.07           1                817.07 Vendedor 10    2023-06-28
#          345 Cliente Genérico 14  Produto Eletrônico 6 566.94           4               2267.76  Vendedor 8    2023-06-29
#          354 Cliente Genérico 27  Produto Eletrônico 9 184.82           3                554.46  Vendedor 7    2023-06-30
#           19 Cliente Genérico 22  Produto Eletrônico 2 128.36           1                128.36  Vendedor 6    2023-07-01
#          116  Cliente Genérico 9  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 8    2023-07-01
#            7 Cliente Genérico 26  Produto Eletrônico 3 817.07           5               4085.35  Vendedor 6    2023-07-03
#          243 Cliente Genérico 16 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 5    2023-07-04
#          239 Cliente Genérico 21  Produto Eletrônico 5 606.13           3               1818.39  Vendedor 3    2023-07-04
#          369 Cliente Genérico 16  Produto Eletrônico 7 823.36           4               3293.44  Vendedor 7    2023-07-05
#          246 Cliente Genérico 14  Produto Eletrônico 2 128.36           2                256.72  Vendedor 1    2023-07-07
#          119 Cliente Genérico 30  Produto Eletrônico 2 128.36           4                513.44  Vendedor 6    2023-07-07
#           10 Cliente Genérico 24  Produto Eletrônico 4 787.79           5               3938.95  Vendedor 8    2023-07-08
#           83 Cliente Genérico 19  Produto Eletrônico 9 184.82           2                369.64  Vendedor 6    2023-07-08
#          166  Cliente Genérico 1  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 8    2023-07-09
#           79  Cliente Genérico 2  Produto Eletrônico 4 787.79           3               2363.37  Vendedor 6    2023-07-10
#           22 Cliente Genérico 14  Produto Eletrônico 1 954.15           5               4770.75  Vendedor 3    2023-07-14
#          176 Cliente Genérico 24  Produto Eletrônico 7 823.36           3               2470.08 Vendedor 10    2023-07-18
#          268  Cliente Genérico 5  Produto Eletrônico 5 606.13           1                606.13  Vendedor 8    2023-07-19
#          154 Cliente Genérico 12 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 9    2023-07-20
#          193  Cliente Genérico 3  Produto Eletrônico 4 787.79           4               3151.16  Vendedor 6    2023-07-20
#            5 Cliente Genérico 10  Produto Eletrônico 5 606.13           1                606.13  Vendedor 9    2023-07-21
#          139 Cliente Genérico 14  Produto Eletrônico 7 823.36           2               1646.72  Vendedor 6    2023-07-21
#          313 Cliente Genérico 30  Produto Eletrônico 7 823.36           3               2470.08  Vendedor 9    2023-07-23
#          235 Cliente Genérico 30 Produto Eletrônico 10 455.52           4               1822.08 Vendedor 10    2023-07-24
#          111 Cliente Genérico 22  Produto Eletrônico 6 566.94           1                566.94  Vendedor 8    2023-07-24
#          381 Cliente Genérico 30  Produto Eletrônico 4 787.79           1                787.79  Vendedor 7    2023-07-24
#          331  Cliente Genérico 7  Produto Eletrônico 8 535.68           1                535.68  Vendedor 5    2023-07-24
#          236 Cliente Genérico 12  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 5    2023-07-25
#          275 Cliente Genérico 17  Produto Eletrônico 9 184.82           2                369.64  Vendedor 3    2023-07-27
#          342 Cliente Genérico 18  Produto Eletrônico 7 823.36           2               1646.72  Vendedor 2    2023-07-28
#          191 Cliente Genérico 27  Produto Eletrônico 9 184.82           3                554.46 Vendedor 10    2023-07-30
#          206 Cliente Genérico 19  Produto Eletrônico 9 184.82           5                924.10  Vendedor 6    2023-08-02
#           24  Cliente Genérico 6  Produto Eletrônico 2 128.36           3                385.08 Vendedor 10    2023-08-02
#          181 Cliente Genérico 20  Produto Eletrônico 5 606.13           4               2424.52 Vendedor 10    2023-08-03
#          152 Cliente Genérico 27 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 5    2023-08-03
#          112 Cliente Genérico 26  Produto Eletrônico 1 954.15           1                954.15  Vendedor 4    2023-08-04
#           31 Cliente Genérico 20  Produto Eletrônico 2 128.36           4                513.44  Vendedor 5    2023-08-05
#          349 Cliente Genérico 14  Produto Eletrônico 3 817.07           4               3268.28  Vendedor 5    2023-08-05
#          256 Cliente Genérico 20  Produto Eletrônico 5 606.13           5               3030.65  Vendedor 7    2023-08-05
#          229 Cliente Genérico 22 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 5    2023-08-06
#          283  Cliente Genérico 7  Produto Eletrônico 4 787.79           4               3151.16  Vendedor 1    2023-08-07
#           41 Cliente Genérico 12  Produto Eletrônico 3 817.07           1                817.07  Vendedor 4    2023-08-07
#          366 Cliente Genérico 16  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 2    2023-08-07
#          353  Cliente Genérico 1  Produto Eletrônico 2 128.36           3                385.08  Vendedor 8    2023-08-08
#          122 Cliente Genérico 30  Produto Eletrônico 3 817.07           2               1634.14  Vendedor 8    2023-08-08
#          197 Cliente Genérico 28  Produto Eletrônico 2 128.36           1                128.36  Vendedor 1    2023-08-10
#          106 Cliente Genérico 23  Produto Eletrônico 2 128.36           3                385.08  Vendedor 7    2023-08-10
#          149 Cliente Genérico 12  Produto Eletrônico 3 817.07           5               4085.35  Vendedor 6    2023-08-12
#          306  Cliente Genérico 8  Produto Eletrônico 3 817.07           1                817.07  Vendedor 2    2023-08-14
#           28 Cliente Genérico 25  Produto Eletrônico 4 787.79           1                787.79  Vendedor 9    2023-08-16
#          160 Cliente Genérico 24  Produto Eletrônico 9 184.82           2                369.64  Vendedor 1    2023-08-19
#           36 Cliente Genérico 24 Produto Eletrônico 10 455.52           5               2277.60  Vendedor 2    2023-08-20
#          340 Cliente Genérico 27 Produto Eletrônico 10 455.52           1                455.52  Vendedor 1    2023-08-21
#          163 Cliente Genérico 23  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 5    2023-08-21
#          108 Cliente Genérico 11  Produto Eletrônico 8 535.68           2               1071.36  Vendedor 4    2023-08-22
#          104 Cliente Genérico 25  Produto Eletrônico 8 535.68           4               2142.72  Vendedor 8    2023-08-23
#          399 Cliente Genérico 12  Produto Eletrônico 1 954.15           1                954.15  Vendedor 9    2023-08-25
#          364  Cliente Genérico 2  Produto Eletrônico 8 535.68           2               1071.36  Vendedor 1    2023-08-26
#           17 Cliente Genérico 23 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 9    2023-08-28
#          397  Cliente Genérico 1  Produto Eletrônico 5 606.13           1                606.13  Vendedor 5    2023-08-28
#          158  Cliente Genérico 2  Produto Eletrônico 3 817.07           1                817.07  Vendedor 4    2023-08-29
#           67 Cliente Genérico 23 Produto Eletrônico 10 455.52           1                455.52  Vendedor 9    2023-08-31
#          304  Cliente Genérico 1  Produto Eletrônico 1 954.15           4               3816.60 Vendedor 10    2023-08-31
#          357  Cliente Genérico 1  Produto Eletrônico 3 817.07           2               1634.14  Vendedor 1    2023-09-01
#          367 Cliente Genérico 13  Produto Eletrônico 6 566.94           4               2267.76  Vendedor 3    2023-09-03
#          221 Cliente Genérico 11 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 1    2023-09-05
#          103 Cliente Genérico 11  Produto Eletrônico 4 787.79           5               3938.95  Vendedor 4    2023-09-07
#           51 Cliente Genérico 28  Produto Eletrônico 6 566.94           2               1133.88  Vendedor 2    2023-09-07
#           68  Cliente Genérico 8  Produto Eletrônico 5 606.13           4               2424.52  Vendedor 9    2023-09-08
#          199 Cliente Genérico 28  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 3    2023-09-08
#          161 Cliente Genérico 21  Produto Eletrônico 2 128.36           2                256.72  Vendedor 5    2023-09-08
#          179 Cliente Genérico 22  Produto Eletrônico 9 184.82           3                554.46  Vendedor 7    2023-09-10
#          398  Cliente Genérico 2  Produto Eletrônico 5 606.13           4               2424.52 Vendedor 10    2023-09-12
#           81  Cliente Genérico 7  Produto Eletrônico 8 535.68           4               2142.72  Vendedor 3    2023-09-14
#           78 Cliente Genérico 12  Produto Eletrônico 8 535.68           4               2142.72  Vendedor 7    2023-09-14
#           20 Cliente Genérico 21 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 5    2023-09-14
#          240 Cliente Genérico 19  Produto Eletrônico 4 787.79           1                787.79  Vendedor 1    2023-09-15
#          297 Cliente Genérico 23 Produto Eletrônico 10 455.52           5               2277.60 Vendedor 10    2023-09-16
#          385  Cliente Genérico 7  Produto Eletrônico 6 566.94           2               1133.88  Vendedor 9    2023-09-16
#          320 Cliente Genérico 29  Produto Eletrônico 2 128.36           5                641.80  Vendedor 7    2023-09-16
#          395 Cliente Genérico 28  Produto Eletrônico 2 128.36           4                513.44  Vendedor 9    2023-09-17
#          318 Cliente Genérico 23  Produto Eletrônico 4 787.79           2               1575.58  Vendedor 8    2023-09-17
#          250 Cliente Genérico 17  Produto Eletrônico 2 128.36           5                641.80  Vendedor 8    2023-09-17
#          196  Cliente Genérico 8  Produto Eletrônico 1 954.15           4               3816.60 Vendedor 10    2023-09-18
#          204 Cliente Genérico 20  Produto Eletrônico 5 606.13           2               1212.26  Vendedor 4    2023-09-19
#           89 Cliente Genérico 25 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 6    2023-09-19
#          382 Cliente Genérico 30  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 5    2023-09-19
#          261 Cliente Genérico 17  Produto Eletrônico 2 128.36           3                385.08  Vendedor 1    2023-09-19
#          124 Cliente Genérico 12  Produto Eletrônico 4 787.79           2               1575.58  Vendedor 8    2023-09-20
#          178 Cliente Genérico 20  Produto Eletrônico 1 954.15           1                954.15  Vendedor 6    2023-09-20
#           97 Cliente Genérico 10  Produto Eletrônico 8 535.68           1                535.68  Vendedor 3    2023-09-20
#          332 Cliente Genérico 23  Produto Eletrônico 8 535.68           1                535.68  Vendedor 4    2023-09-21
#          198 Cliente Genérico 24  Produto Eletrônico 6 566.94           3               1700.82  Vendedor 2    2023-09-22
#          279 Cliente Genérico 26  Produto Eletrônico 6 566.94           2               1133.88  Vendedor 5    2023-09-22
#           94 Cliente Genérico 12  Produto Eletrônico 8 535.68           3               1607.04  Vendedor 4    2023-09-23
#          230 Cliente Genérico 19  Produto Eletrônico 9 184.82           2                369.64  Vendedor 8    2023-09-23
#          183  Cliente Genérico 2  Produto Eletrônico 9 184.82           5                924.10 Vendedor 10    2023-09-23
#          327  Cliente Genérico 2  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 1    2023-09-27
#           39 Cliente Genérico 29 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 8    2023-09-28
#           21  Cliente Genérico 2  Produto Eletrônico 9 184.82           1                184.82  Vendedor 7    2023-09-29
#          185 Cliente Genérico 29  Produto Eletrônico 6 566.94           3               1700.82  Vendedor 4    2023-10-01
#           96 Cliente Genérico 10  Produto Eletrônico 2 128.36           4                513.44  Vendedor 8    2023-10-02
#          133  Cliente Genérico 5  Produto Eletrônico 9 184.82           4                739.28 Vendedor 10    2023-10-03
#          376 Cliente Genérico 15  Produto Eletrônico 3 817.07           5               4085.35  Vendedor 6    2023-10-04
#          225 Cliente Genérico 25  Produto Eletrônico 6 566.94           5               2834.70  Vendedor 3    2023-10-05
#          323 Cliente Genérico 30  Produto Eletrônico 5 606.13           3               1818.39  Vendedor 4    2023-10-05
#          147 Cliente Genérico 21  Produto Eletrônico 9 184.82           2                369.64 Vendedor 10    2023-10-06
#          205 Cliente Genérico 18  Produto Eletrônico 9 184.82           3                554.46 Vendedor 10    2023-10-08
#          386 Cliente Genérico 29  Produto Eletrônico 4 787.79           5               3938.95  Vendedor 9    2023-10-08
#          186 Cliente Genérico 21  Produto Eletrônico 9 184.82           4                739.28 Vendedor 10    2023-10-08
#          114 Cliente Genérico 13  Produto Eletrônico 4 787.79           4               3151.16  Vendedor 1    2023-10-08
#          138 Cliente Genérico 26  Produto Eletrônico 7 823.36           4               3293.44  Vendedor 9    2023-10-09
#          231 Cliente Genérico 14  Produto Eletrônico 6 566.94           5               2834.70  Vendedor 2    2023-10-09
#           85 Cliente Genérico 21  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 5    2023-10-10
#          325 Cliente Genérico 17  Produto Eletrônico 9 184.82           1                184.82  Vendedor 2    2023-10-10
#          170 Cliente Genérico 26  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 6    2023-10-13
#           84 Cliente Genérico 28  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 4    2023-10-14
#          312 Cliente Genérico 17 Produto Eletrônico 10 455.52           5               2277.60  Vendedor 3    2023-10-14
#           29  Cliente Genérico 3  Produto Eletrônico 1 954.15           2               1908.30  Vendedor 7    2023-10-15
#          202 Cliente Genérico 20  Produto Eletrônico 8 535.68           4               2142.72  Vendedor 6    2023-10-15
#           90 Cliente Genérico 29  Produto Eletrônico 6 566.94           1                566.94  Vendedor 9    2023-10-16
#          177 Cliente Genérico 13  Produto Eletrônico 9 184.82           2                369.64 Vendedor 10    2023-10-17
#          300 Cliente Genérico 10  Produto Eletrônico 5 606.13           1                606.13  Vendedor 6    2023-10-18
#           73 Cliente Genérico 30 Produto Eletrônico 10 455.52           5               2277.60  Vendedor 6    2023-10-20
#           99 Cliente Genérico 13  Produto Eletrônico 9 184.82           2                369.64  Vendedor 4    2023-10-21
#          267  Cliente Genérico 9  Produto Eletrônico 4 787.79           4               3151.16  Vendedor 6    2023-10-21
#          337  Cliente Genérico 5  Produto Eletrônico 5 606.13           4               2424.52  Vendedor 9    2023-10-22
#           59 Cliente Genérico 17  Produto Eletrônico 9 184.82           4                739.28 Vendedor 10    2023-10-22
#          335  Cliente Genérico 1  Produto Eletrônico 5 606.13           3               1818.39  Vendedor 7    2023-10-22
#          217 Cliente Genérico 30  Produto Eletrônico 5 606.13           1                606.13  Vendedor 2    2023-10-22
#          223 Cliente Genérico 14  Produto Eletrônico 1 954.15           5               4770.75  Vendedor 2    2023-10-23
#            9 Cliente Genérico 17  Produto Eletrônico 1 954.15           2               1908.30  Vendedor 7    2023-10-23
#          208 Cliente Genérico 16  Produto Eletrônico 7 823.36           1                823.36  Vendedor 9    2023-10-24
#          288 Cliente Genérico 28  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 3    2023-10-25
#          113  Cliente Genérico 2 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 9    2023-10-26
#          143 Cliente Genérico 19 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 9    2023-10-26
#          245 Cliente Genérico 29  Produto Eletrônico 8 535.68           4               2142.72  Vendedor 5    2023-10-28
#          132 Cliente Genérico 19  Produto Eletrônico 5 606.13           2               1212.26  Vendedor 8    2023-10-29
#          173 Cliente Genérico 16  Produto Eletrônico 3 817.07           4               3268.28  Vendedor 7    2023-10-29
#          233 Cliente Genérico 17  Produto Eletrônico 8 535.68           4               2142.72  Vendedor 6    2023-10-30
#          333  Cliente Genérico 8  Produto Eletrônico 6 566.94           1                566.94  Vendedor 5    2023-10-30
#          131 Cliente Genérico 14  Produto Eletrônico 4 787.79           1                787.79  Vendedor 1    2023-10-31
#          107  Cliente Genérico 5  Produto Eletrônico 2 128.36           1                128.36  Vendedor 8    2023-11-02
#          309 Cliente Genérico 15  Produto Eletrônico 2 128.36           1                128.36  Vendedor 2    2023-11-02
#          290  Cliente Genérico 3  Produto Eletrônico 7 823.36           1                823.36  Vendedor 6    2023-11-02
#          219 Cliente Genérico 28  Produto Eletrônico 6 566.94           1                566.94  Vendedor 8    2023-11-03
#          252 Cliente Genérico 29  Produto Eletrônico 7 823.36           3               2470.08  Vendedor 6    2023-11-05
#          311 Cliente Genérico 13  Produto Eletrônico 4 787.79           1                787.79  Vendedor 1    2023-11-06
#           38  Cliente Genérico 5  Produto Eletrônico 1 954.15           4               3816.60 Vendedor 10    2023-11-06
#          271  Cliente Genérico 7  Produto Eletrônico 4 787.79           3               2363.37  Vendedor 3    2023-11-07
#          341  Cliente Genérico 3  Produto Eletrônico 6 566.94           3               1700.82  Vendedor 7    2023-11-10
#          281 Cliente Genérico 10  Produto Eletrônico 4 787.79           1                787.79  Vendedor 2    2023-11-13
#          148 Cliente Genérico 10  Produto Eletrônico 9 184.82           1                184.82  Vendedor 7    2023-11-14
#           30 Cliente Genérico 27  Produto Eletrônico 6 566.94           5               2834.70  Vendedor 4    2023-11-15
#           27 Cliente Genérico 10  Produto Eletrônico 1 954.15           3               2862.45 Vendedor 10    2023-11-15
#          330  Cliente Genérico 8  Produto Eletrônico 7 823.36           1                823.36  Vendedor 3    2023-11-18
#           25 Cliente Genérico 25  Produto Eletrônico 2 128.36           3                385.08  Vendedor 5    2023-11-20
#          383 Cliente Genérico 19  Produto Eletrônico 7 823.36           2               1646.72  Vendedor 4    2023-11-20
#            2 Cliente Genérico 27  Produto Eletrônico 4 787.79           1                787.79  Vendedor 8    2023-11-22
#           33  Cliente Genérico 1  Produto Eletrônico 2 128.36           2                256.72  Vendedor 4    2023-11-23
#          319 Cliente Genérico 21  Produto Eletrônico 4 787.79           1                787.79  Vendedor 9    2023-11-24
#          310 Cliente Genérico 18  Produto Eletrônico 3 817.07           4               3268.28  Vendedor 7    2023-11-25
#          298 Cliente Genérico 12  Produto Eletrônico 4 787.79           3               2363.37  Vendedor 1    2023-11-26
#           11 Cliente Genérico 10  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 1    2023-11-29
#          387 Cliente Genérico 23  Produto Eletrônico 6 566.94           5               2834.70 Vendedor 10    2023-12-01
#          137 Cliente Genérico 23  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 1    2023-12-02
#          274  Cliente Genérico 7  Produto Eletrônico 3 817.07           2               1634.14  Vendedor 2    2023-12-03
#          321 Cliente Genérico 28  Produto Eletrônico 8 535.68           3               1607.04  Vendedor 6    2023-12-03
#          110 Cliente Genérico 13  Produto Eletrônico 2 128.36           2                256.72  Vendedor 3    2023-12-03
#          301 Cliente Genérico 10  Produto Eletrônico 9 184.82           5                924.10  Vendedor 6    2023-12-04
#          396 Cliente Genérico 23 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 3    2023-12-05
#           26 Cliente Genérico 17  Produto Eletrônico 4 787.79           4               3151.16  Vendedor 7    2023-12-06
#          351 Cliente Genérico 27 Produto Eletrônico 10 455.52           1                455.52  Vendedor 1    2023-12-06
#          282 Cliente Genérico 26  Produto Eletrônico 3 817.07           1                817.07  Vendedor 1    2023-12-07
#          232  Cliente Genérico 8  Produto Eletrônico 1 954.15           5               4770.75  Vendedor 2    2023-12-11
#          194 Cliente Genérico 18  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 7    2023-12-14
#          378 Cliente Genérico 22  Produto Eletrônico 1 954.15           3               2862.45  Vendedor 7    2023-12-14
#           74  Cliente Genérico 6  Produto Eletrônico 7 823.36           3               2470.08  Vendedor 5    2023-12-15
#          125  Cliente Genérico 6  Produto Eletrônico 1 954.15           5               4770.75  Vendedor 4    2023-12-16
#          155 Cliente Genérico 30  Produto Eletrônico 7 823.36           3               2470.08  Vendedor 7    2023-12-16
#          249 Cliente Genérico 25  Produto Eletrônico 5 606.13           2               1212.26  Vendedor 4    2023-12-17
#           47 Cliente Genérico 30  Produto Eletrônico 2 128.36           5                641.80  Vendedor 2    2023-12-18
#          394 Cliente Genérico 13  Produto Eletrônico 9 184.82           1                184.82  Vendedor 4    2023-12-19
#          362 Cliente Genérico 21  Produto Eletrônico 5 606.13           1                606.13  Vendedor 2    2023-12-20
#          352 Cliente Genérico 16  Produto Eletrônico 2 128.36           3                385.08  Vendedor 7    2023-12-20
#          299  Cliente Genérico 9  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 3    2023-12-23
#          175 Cliente Genérico 14  Produto Eletrônico 6 566.94           3               1700.82 Vendedor 10    2023-12-23
#           76 Cliente Genérico 16  Produto Eletrônico 7 823.36           5               4116.80  Vendedor 1    2023-12-24
#          269 Cliente Genérico 15  Produto Eletrônico 8 535.68           5               2678.40 Vendedor 10    2023-12-25
#          361 Cliente Genérico 28  Produto Eletrônico 4 787.79           3               2363.37  Vendedor 1    2023-12-26
#            8 Cliente Genérico 26  Produto Eletrônico 9 184.82           1                184.82  Vendedor 2    2023-12-26
#          255 Cliente Genérico 11  Produto Eletrônico 4 787.79           5               3938.95  Vendedor 2    2023-12-26
#          289  Cliente Genérico 7  Produto Eletrônico 9 184.82           4                739.28  Vendedor 5    2023-12-28
#           37 Cliente Genérico 14 Produto Eletrônico 10 455.52           2                911.04  Vendedor 6    2023-12-28
#          277  Cliente Genérico 7  Produto Eletrônico 9 184.82           1                184.82 Vendedor 10    2023-12-29
#          241 Cliente Genérico 17  Produto Eletrônico 2 128.36           2                256.72  Vendedor 6    2023-12-29
#          266 Cliente Genérico 26  Produto Eletrônico 8 535.68           1                535.68  Vendedor 4    2024-01-02
#          195 Cliente Genérico 21 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 3    2024-01-02
#          140  Cliente Genérico 3  Produto Eletrônico 6 566.94           3               1700.82  Vendedor 9    2024-01-04
#          302  Cliente Genérico 6  Produto Eletrônico 1 954.15           1                954.15  Vendedor 9    2024-01-05
#          388 Cliente Genérico 27  Produto Eletrônico 1 954.15           5               4770.75 Vendedor 10    2024-01-05
#          372 Cliente Genérico 29  Produto Eletrônico 8 535.68           3               1607.04  Vendedor 8    2024-01-09
#          102 Cliente Genérico 12  Produto Eletrônico 5 606.13           3               1818.39  Vendedor 7    2024-01-09
#          182  Cliente Genérico 9 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 6    2024-01-12
#            1 Cliente Genérico 18  Produto Eletrônico 2 128.36           5                641.80  Vendedor 2    2024-01-13
#           23  Cliente Genérico 5  Produto Eletrônico 3 817.07           2               1634.14 Vendedor 10    2024-01-15
#          270 Cliente Genérico 27 Produto Eletrônico 10 455.52           4               1822.08 Vendedor 10    2024-01-15
#           95 Cliente Genérico 19  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 4    2024-01-15
#           55  Cliente Genérico 5  Produto Eletrônico 2 128.36           2                256.72  Vendedor 9    2024-01-16
#          135 Cliente Genérico 27  Produto Eletrônico 5 606.13           2               1212.26  Vendedor 7    2024-01-16
#          165 Cliente Genérico 28  Produto Eletrônico 8 535.68           2               1071.36  Vendedor 7    2024-01-16
#          105 Cliente Genérico 24  Produto Eletrônico 8 535.68           4               2142.72  Vendedor 3    2024-01-17
#          134 Cliente Genérico 14  Produto Eletrônico 4 787.79           2               1575.58  Vendedor 5    2024-01-17
#          296  Cliente Genérico 4  Produto Eletrônico 7 823.36           1                823.36  Vendedor 9    2024-01-18
#          291 Cliente Genérico 15  Produto Eletrônico 4 787.79           2               1575.58  Vendedor 7    2024-01-18
#          118  Cliente Genérico 4  Produto Eletrônico 1 954.15           3               2862.45  Vendedor 3    2024-01-18
#           13 Cliente Genérico 27  Produto Eletrônico 7 823.36           1                823.36 Vendedor 10    2024-01-19
#          115 Cliente Genérico 18  Produto Eletrônico 7 823.36           5               4116.80  Vendedor 2    2024-01-20
#          172  Cliente Genérico 6  Produto Eletrônico 9 184.82           3                554.46  Vendedor 5    2024-01-20
#           18  Cliente Genérico 9  Produto Eletrônico 3 817.07           5               4085.35  Vendedor 7    2024-01-22
#           14 Cliente Genérico 30  Produto Eletrônico 1 954.15           1                954.15  Vendedor 9    2024-01-23
#           58  Cliente Genérico 8  Produto Eletrônico 6 566.94           5               2834.70  Vendedor 3    2024-01-23
#          276  Cliente Genérico 9  Produto Eletrônico 3 817.07           4               3268.28  Vendedor 6    2024-01-24
#           40 Cliente Genérico 15  Produto Eletrônico 1 954.15           1                954.15  Vendedor 6    2024-01-26
#          159  Cliente Genérico 5  Produto Eletrônico 5 606.13           5               3030.65  Vendedor 5    2024-01-27
#           50 Cliente Genérico 10  Produto Eletrônico 1 954.15           1                954.15  Vendedor 5    2024-01-27
#          326 Cliente Genérico 30 Produto Eletrônico 10 455.52           3               1366.56  Vendedor 5    2024-01-27
#          273  Cliente Genérico 2  Produto Eletrônico 5 606.13           1                606.13  Vendedor 8    2024-01-28
#           57 Cliente Genérico 27  Produto Eletrônico 3 817.07           3               2451.21  Vendedor 4    2024-01-30
#          127  Cliente Genérico 3  Produto Eletrônico 3 817.07           1                817.07  Vendedor 4    2024-02-01
#           52  Cliente Genérico 6  Produto Eletrônico 6 566.94           1                566.94  Vendedor 7    2024-02-02
#          358  Cliente Genérico 2  Produto Eletrônico 1 954.15           1                954.15  Vendedor 9    2024-02-03
#          390 Cliente Genérico 27  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 8    2024-02-04
#          130 Cliente Genérico 24  Produto Eletrônico 7 823.36           4               3293.44  Vendedor 8    2024-02-04
#          153  Cliente Genérico 9  Produto Eletrônico 5 606.13           5               3030.65  Vendedor 9    2024-02-05
#          254  Cliente Genérico 2  Produto Eletrônico 7 823.36           5               4116.80  Vendedor 3    2024-02-05
#          377 Cliente Genérico 13  Produto Eletrônico 8 535.68           1                535.68  Vendedor 7    2024-02-06
#          343 Cliente Genérico 28  Produto Eletrônico 1 954.15           5               4770.75  Vendedor 1    2024-02-06
#          370  Cliente Genérico 4  Produto Eletrônico 8 535.68           1                535.68  Vendedor 2    2024-02-06
#          316 Cliente Genérico 28  Produto Eletrônico 3 817.07           2               1634.14  Vendedor 1    2024-02-07
#           44 Cliente Genérico 11  Produto Eletrônico 3 817.07           5               4085.35  Vendedor 3    2024-02-10
#          192 Cliente Genérico 16  Produto Eletrônico 6 566.94           5               2834.70  Vendedor 7    2024-02-11
#           80 Cliente Genérico 16  Produto Eletrônico 9 184.82           4                739.28  Vendedor 3    2024-02-12
#          278 Cliente Genérico 23  Produto Eletrônico 1 954.15           1                954.15  Vendedor 4    2024-02-13
#          100 Cliente Genérico 25  Produto Eletrônico 5 606.13           3               1818.39  Vendedor 5    2024-02-14
#          242 Cliente Genérico 29 Produto Eletrônico 10 455.52           5               2277.60  Vendedor 1    2024-02-15
#          150 Cliente Genérico 22  Produto Eletrônico 9 184.82           2                369.64  Vendedor 8    2024-02-19
#          224 Cliente Genérico 11  Produto Eletrônico 1 954.15           4               3816.60  Vendedor 8    2024-02-19
#          156 Cliente Genérico 22  Produto Eletrônico 6 566.94           3               1700.82  Vendedor 7    2024-02-20
#          374  Cliente Genérico 2 Produto Eletrônico 10 455.52           5               2277.60  Vendedor 9    2024-02-20
#          238  Cliente Genérico 2  Produto Eletrônico 7 823.36           4               3293.44  Vendedor 8    2024-02-21
#           61 Cliente Genérico 11  Produto Eletrônico 4 787.79           2               1575.58  Vendedor 7    2024-02-21
#          169 Cliente Genérico 29  Produto Eletrônico 8 535.68           5               2678.40  Vendedor 9    2024-02-22
#          315 Cliente Genérico 18  Produto Eletrônico 2 128.36           4                513.44  Vendedor 5    2024-02-23
#           62 Cliente Genérico 22  Produto Eletrônico 1 954.15           3               2862.45  Vendedor 6    2024-02-23
#          308 Cliente Genérico 11  Produto Eletrônico 2 128.36           1                128.36  Vendedor 5    2024-02-24
#          215 Cliente Genérico 30 Produto Eletrônico 10 455.52           4               1822.08  Vendedor 5    2024-02-24
#          188  Cliente Genérico 5  Produto Eletrônico 3 817.07           3               2451.21 Vendedor 10    2024-02-24
#            3  Cliente Genérico 5  Produto Eletrônico 9 184.82           4                739.28  Vendedor 8    2024-02-24
#          244 Cliente Genérico 17  Produto Eletrônico 8 535.68           1                535.68 Vendedor 10    2024-02-28
#           98  Cliente Genérico 4  Produto Eletrônico 5 606.13           5               3030.65  Vendedor 9    2024-02-28
#           72  Cliente Genérico 7  Produto Eletrônico 2 128.36           1                128.36  Vendedor 7    2024-02-29
#          128 Cliente Genérico 26  Produto Eletrônico 9 184.82           4                739.28  Vendedor 5    2024-02-29
#           34 Cliente Genérico 25  Produto Eletrônico 1 954.15           2               1908.30  Vendedor 4    2024-02-29
#          262  Cliente Genérico 1  Produto Eletrônico 7 823.36           2               1646.72  Vendedor 9    2024-03-01
#          389 Cliente Genérico 14 Produto Eletrônico 10 455.52           3               1366.56 Vendedor 10    2024-03-01

# %%
df
# Out:
#      ID da Venda              Cliente                Produto   Preço  \
# 0            392  Cliente Genérico 29   Produto Eletrônico 1  954.15
# 1            259   Cliente Genérico 9   Produto Eletrônico 3  817.07
# 2            393  Cliente Genérico 23   Produto Eletrônico 8  535.68
# 3            117   Cliente Genérico 6   Produto Eletrônico 5  606.13
# 4            375  Cliente Genérico 25  Produto Eletrônico 10  455.52
# ..           ...                  ...                    ...     ...
# 394           72   Cliente Genérico 7   Produto Eletrônico 2  128.36
# 395          128  Cliente Genérico 26   Produto Eletrônico 9  184.82
# 396           34  Cliente Genérico 25   Produto Eletrônico 1  954.15
# 397          262   Cliente Genérico 1   Produto Eletrônico 7  823.36
# 398          389  Cliente Genérico 14  Produto Eletrônico 10  455.52
#
#      Quantidade  Valor Total da Venda     Vendedor Data da Venda
# 0             5               4770.75   Vendedor 2    2023-03-04
# 1             5               4085.35   Vendedor 2    2023-03-07
# 2             2               1071.36   Vendedor 8    2023-03-08
# 3             4               2424.52  Vendedor 10    2023-03-08
# 4             2                911.04   Vendedor 3    2023-03-08
# ..          ...                   ...          ...           ...
# 394           1                128.36   Vendedor 7    2024-02-29
# 395           4                739.28   Vendedor 5    2024-02-29
# 396           2               1908.30   Vendedor 4    2024-02-29
# 397           2               1646.72   Vendedor 9    2024-03-01
# 398           3               1366.56  Vendedor 10    2024-03-01
#
# [399 rows x 8 columns]

# %%
data = input("Digite da data: ")
formato = "%Y-%m-%d"
data_datetime = datetime.strptime(data, formato)
produto = input("Digite o código do produto: ")

try:
    cursor.execute("""
        SELECT v.venda_id, c.nome AS cliente_nome, p.nome AS produto_nome, p.preco, v.quantidade,
        (p.preco * v.quantidade) AS valor_total_venda, vd.nome AS vendedor_nome, v.data_venda
        FROM vendas v
        JOIN clientes c ON v.cliente_id = c.cliente_id
        JOIN produtos p ON v.produto_id = p.produto_id
        JOIN vendedores vd ON v.vendedor_id = vd.vendedor_id
        WHERE v.data_venda = :data_datetime -- AND v.produto_id = :produto
        ORDER BY v.data_venda DESC
    """, [data_datetime])

    results = cursor.fetchall()

    if results:
        df = pd.DataFrame(results, columns=['ID Venda', 'Nome Cliente', 'Nome Produto', 'Preço', 'Quantidade', 'Valor Total Venda', 'Nome Vendedor', 'Data Venda'])
        print(df)
    else:
        print("Nenhuma compra encontrada para a data e/ou produto informado.")
except cx_Oracle.DatabaseError as e:
    print("Erro ao buscar compras da data:", e)
# Out:
# Digite da data: 2024-01-27
# Digite o código do produto:
#    ID Venda         Nome Cliente           Nome Produto   Preço  Quantidade  \
# 0        50  Cliente Genérico 10   Produto Eletrônico 1  954.15           1
# 1       159   Cliente Genérico 5   Produto Eletrônico 5  606.13           5
# 2       326  Cliente Genérico 30  Produto Eletrônico 10  455.52           3
#
#    Valor Total Venda Nome Vendedor Data Venda
# 0             954.15    Vendedor 5 2024-01-27
# 1            3030.65    Vendedor 5 2024-01-27
# 2            1366.56    Vendedor 5 2024-01-27

# %%
df
# Out:
#    ID Venda         Nome Cliente           Nome Produto   Preço  Quantidade  \
# 0        50  Cliente Genérico 10   Produto Eletrônico 1  954.15           1
# 1       159   Cliente Genérico 5   Produto Eletrônico 5  606.13           5
# 2       326  Cliente Genérico 30  Produto Eletrônico 10  455.52           3
#
#    Valor Total Venda Nome Vendedor Data Venda
# 0             954.15    Vendedor 5 2024-01-27
# 1            3030.65    Vendedor 5 2024-01-27
# 2            1366.56    Vendedor 5 2024-01-27

# %%
df.columns
# Out:
# Index(['ID Venda', 'Nome Cliente', 'Nome Produto', 'Preço', 'Quantidade',
#        'Valor Total Venda', 'Nome Vendedor', 'Data Venda'],
#       dtype='object')

# %%
df.groupby('Data Venda')['Valor Total Venda'].describe()
# Out:
#             count         mean          std     min       25%      50%  \
# Data Venda
# 2024-01-27    3.0  1783.786667  1099.327809  954.15  1160.355  1366.56
#
#                  75%      max
# Data Venda
# 2024-01-27  2198.605  3030.65

# %%
# Inserindo dados em 'vendas' com valores aleatórios
for i in range(202, 401):
    data_venda = datetime.now() - timedelta(days=random.randint(1, 365))
    cursor.execute(f"""
        INSERT INTO vendas (venda_id, cliente_id, produto_id, vendedor_id, quantidade, data_venda)
        VALUES ({i}, {random.randint(1, 30)}, {random.randint(1, 10)}, {random.randint(1, 10)}, {random.randint(1, 5)}, TO_DATE('{data_venda.strftime('%Y-%m-%d')}', 'YYYY-MM-DD'))
    """)
connection.commit()
