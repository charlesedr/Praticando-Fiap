# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/diogenesjusto/FIAP/master/Gradua%C3%A7%C3%A3o/dados/diamonds.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
# Cálculo da média (aritmética) da variável price na populução
df[['price']].mean()
# Out:
# price    3932.799722
# dtype: float64

# %%
#Calcular a mediana do preço
df[['price']].median()
# Out:
# price    2401.0
# dtype: float64

# %%
#calcular o maior preço
df[['price']].max()
# Out:
# price    18823
# dtype: int64

# %%
#calcular o menor preço
df[['price']].min()
# Out:
# price    326
# dtype: int64

# %%
df[['carat']].mean()
# Out:
# carat    0.79794
# dtype: float64

# %%
# Cálculo da mediana da variável price na populução
df[['price']].median()
# Out:
# price    2401.0
# dtype: float64

# %%
# Cálculo da desvio padrão da variável price na população
df[['price']].std()
# Out:
# price    3989.439738
# dtype: float64

# %%
# Representação da distribuição de dados: histograma
df[['price']].hist( bins = 8)
# Out:
# array([[<Axes: title={'center': 'price'}>]], dtype=object)

# %%
# Amostra de 3000 linhas da linha 3mil até 5999
a1 = df.iloc[3000:5999, :]
a1.head()

''' Intenção é mostrar o que pode dar errado '''
# Out:
# ' Intenção é mostrar o que pode dar errado '

# %%
# Estatísticas descritivas da amostra
a1[['price']].mean()

''' podemos ver q agora a média mudou bastante '''
# Out:
# ' podemos ver q agora a média mudou bastante '

# %%
a1[['price']].median()

''' a mediana já está acima da média, isto é, não é significativa da população '''
''' é interesante tirar as medidas estatisticas tanto da população quanto da amostra '''
# Out:
# ' é interesante tirar as medidas estatisticas tanto da população quanto da amostra '

# %%
a1[['price']].std()
# Out:
# price    941.000147
# dtype: float64

# %%
a1[['price']].hist()
# Out:
# array([[<Axes: title={'center': 'price'}>]], dtype=object)

# %%
# Geração de amostra aleatória (sample é aleatório)
a3 = df.sample(600)
a3.head()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 14737       14738   1.09      Ideal     E     SI1   61.1   55.0   5935  6.66
# 7853         7854   0.90  Very Good     D     SI1   61.0   63.0   4304  6.13
# 35496       35497   0.41  Very Good     F     SI1   63.4   57.0    904  4.74
# 30934       30935   0.24  Very Good     H    VVS2   61.9   57.0    449  3.97
# 46234       46235   0.58      Ideal     E     VS2   62.0   57.0   1752  5.33
#
#           y     z
# 14737  6.70  4.08
# 7853   6.10  3.73
# 35496  4.73  3.00
# 30934  4.01  2.47
# 46234  5.35  3.31

# %%
a3[['price']].mean()
# Out:
# price    4092.153333
# dtype: float64

# %%
df[['price']].mean()
# Out:
# price    3932.799722
# dtype: float64

# %%
a3[['price']].median()
# Out:
# price    2534.5
# dtype: float64

# %%
df[['price']].median()
# Out:
# price    2401.0
# dtype: float64

# %%
df[['price']].mean()
# Out:
# price    3932.799722
# dtype: float64

# %%
df[['price']].median()
# Out:
# price    2401.0
# dtype: float64

# %%
df[['price']].hist()
# Out:
# array([[<Axes: title={'center': 'price'}>]], dtype=object)

# %%
a3[['price']].hist()
# Out:
# array([[<Axes: title={'center': 'price'}>]], dtype=object)

# %%
# Cálculo de decis ou percentis ''' organizando de zero até um de um em um (de 0 a 1), isto é, de 10% em 10% '''
df[['price']].quantile(np.arange(0,1,.1))
# Out:
#       price
# 0.0   326.0
# 0.1   646.0
# 0.2   837.0
# 0.3  1087.0
# 0.4  1698.0
# 0.5  2401.0
# 0.6  3465.0
# 0.7  4662.0
# 0.8  6301.2
# 0.9  9821.0

# %%
a3[['price']].quantile(np.arange(0,1,.1))
# Out:
#        price
# 0.0    365.0
# 0.1    633.0
# 0.2    840.0
# 0.3   1163.7
# 0.4   2093.0
# 0.5   2908.5
# 0.6   4011.0
# 0.7   5169.6
# 0.8   7173.8
# 0.9  11308.7

# %%
# Distribuição de variável categórica na população
df['color'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='color'>

# %%
df['cut'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='cut'>

# %%
# Distribuição de variável categórica na população
df['clarity'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='clarity'>
